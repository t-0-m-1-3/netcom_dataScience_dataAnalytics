# %%
from IPython.display import Image
Image("../src/photos/python.png")

# %% [markdown]
# ## Intro To Python: Part 0
# ----
# There is an over arching philosophy that has probably kept the python community together through thick and thin

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# ### Python Is What?
# ---
# ```
# Python is an interpreted, interactive, object-oriented programming language that combines remarkable power with very clear  syntax.
# ```

# %%
help(object)
# Out:
# Help on class object in module builtins:
#
# class object
#  |  The most base type

# %%
Image("../src/photos/OOp.png")

# %% [markdown]
# ### Object Oriented Programming
# ----
# A coding paradigm in which Obejcts are the main abstraction and actions that occur on those objects of the data they contain are contained in methods.
#
# `Class.method(data_to_act_on)` is the usual callling method

# %%
help('class')
# Out:
# Class definitions
# *****************
#
# A class definition defines a class object (see section The standard
# type hierarchy):
#
#    classdef    ::= [decorators] "class" classname [inheritance] ":" suite
#    inheritance ::= "(" [argument_list] ")"
#    classname   ::= identifier
#
# A class definition is an executable statement.  The inheritance list
# usually gives a list of base classes (see Metaclasses for more
# advanced uses), so each item in the list should evaluate to a class
# object which allows subclassing.  Classes without an inheritance list
# inherit, by default, from the base class "object"; hence,
#
#    class Foo:
#        pass
#
# is equivalent to
#
#    class Foo(object):
#        pass
#
# The class’s suite is then executed in a new execution frame (see
# Naming and binding), using a newly created local namespace and the
# original global namespace. (Usually, the suite contains mostly
# function definitions.)  When the class’s suite finishes execution, its
# ...

# %% [markdown]
# ### Variables in Python
# ----
#
# Variables tell the operating system to reserve some space for information to be stored, manipulated, and retreived later on.
#
# They provide labels for your data, because computer programs are mostly read by humans and interpreted by compilers
#
# You use the _assignment operator_ `=`to declare a variable in python
# ```python
# number = 1
# string = 'word'
# decimal = 0.14
# list = []
# tuple = ()
# key_value_pair = {'key': value}
# set_of_something = {}
# ```

# %%
number = 12
print(number ** 2)
# Out:
# 144

# %% [markdown]
# ## Functions: Built in and Defined:
# ----
# The standard library in Python comes with a large amount of functions predefined for you to use, like the `help()` and `len()` functions.
#
# ```python
# def greet(name):
#     print("Hello " + name)
# ```

# %% [markdown]
# ### Basic Types Inside of Python
# ----
# 1. Numbers ( int and float )
# 2. Strings
# 3. Booleans
# 4. Lists
# 5. Tuples
# 6. Dictionarys
# 7. Sets

# %% [markdown]
# ## Types
# ----
# the `type()` function will let you peek inside the values type

# %% [markdown]
# #### Numbers
# ----
# Ints and Floats

# %%
numbers_and_stuff = 3.14
type(piece_of)
# Out:
# float

# %%
numbers_and_stuff + numbers_and_stuff
# Out:
# 6.28

# %%
print(3 // 14)
three, fourteen = str(numbers_and_stuff).split('.')
print(three, fourteen)
int(three) / int(fourteen)
# Out:
# 0
# 3 14
# 0.21428571428571427

# %% [markdown]
# #### Strings
# ----

# %%
type('hello')
# Out:
# str

# %%
strings = " I've got no strings to hold me down "
print(len(strings))
strings[1:5]
# Out:
# 37
# "I've"

# %%
strings[:7]
# Out:
# " I've g"

# %%
strings[-14:]
# Out:
# ' hold me down '

# %%
strings.upper() * 5
# Out:
# " I'VE GOT NO STRINGS TO HOLD ME DOWN  I'VE GOT NO STRINGS TO HOLD ME DOWN  I'VE GOT NO STRINGS TO HOLD ME DOWN  I'VE GOT NO STRINGS TO HOLD ME DOWN  I'VE GOT NO STRINGS TO HOLD ME DOWN "

# %%
shake_it_up = strings.swapcase().split("'")
shake_it_up * 2
# Out:
# [' i',
#  'VE GOT NO STRINGS TO HOLD ME DOWN ',
#  ' i',
#  'VE GOT NO STRINGS TO HOLD ME DOWN ']

# %% [markdown]
# #### Booleans
# ----
# Perfect for asking and checking for the state of things

# %%
type(False)
# Out:
# bool

# %%
one_fish = 1
two_fish = 2
one_fish < two_fish
# Out:
# True

# %%
print(True + False)
# Out:
# 1

# %%
print(True + True)
# Out:
# 2

# %% [markdown]
# ## Null Values
# ----
# What happens when I have nothing or nothing...yet
# `None`

# %%
result = None
print(result)
# Out:
# None

# %%
result is None
# Out:
# True

# %%
Image("../src/photos/keep_calm_ask.png")

# %% [markdown]
# ### Type Conversion
# ----
# convert the values between different types

# %%
#python supports multiple variable assignment as well
z = x = y = 1
print('x is ' + str(x), '\ny is ' + str(y), '\n \t \t z is ', str(z))
# Out:
# x is 1
# y is 1
#  	 	 z is  1

# %% [markdown]
# ## Arithmetic Operators
# ----
#
# | Symbol        | Task          |
# | ------------- |:-------------:|
# | `+` | Addition |
# | `-` | Subtraction |
# | `/` | Division |
# | `%` | Modulus |
# | `*` | Multiplication |
# | `//`| Floor Division |
# | `**` | The the Power of |

# %%
a_number = 100
another_number = 200

1 + 2 + 3 + 4 + 5 + a_number + another_number
# Out:
# 315

# %% [markdown]
# ### What's the Difference between `/` and `//`
# ----
# Returning an integer vs. returning a float

# %%
1 // 2
# Out:
# 0

# %%
1 / 2
# Out:
# 0.5

# %% [markdown]
# #### :thinking_emoji: but what about??

# %%
10 / 2.0
# Out:
# 5.0

# %% [markdown]
# #### I made a float!!

# %%
12.8 // 6.0
# Out:
# 2.0

# %% [markdown]
# #### Using floor division is nothing but converting the result to the nearest integer

# %% [markdown]
# ## Relational Operators
# ----
#
# | Symbol        | Description          |
# | ------------- |:-------------:|
# | `==` | True, if equal |
# | `!=` | True, if not equal |
# | `<` | less than |
# | `>` | Greater than |
# | `<=` | less than or equal to |
# | `>=`| greater than or equal to |

# %%
n = 1

# %%
n == 1
# Out:
# True

# %%
1 <= 1
# Out:
# True

# %%
n != 1
# Out:
# False

# %% [markdown]
# n > 1

# %%
Image("../src/photos/keep_calm_ask.png")

# %% [markdown]
# #### Logical Operators
# ----
# * Combine two or more comparison operators

# %%
(1 ==1) and (2 == 2)
# Out:
# True

# %%
(1==2) and (2==2)
# Out:
# False

# %%
(1==1) and (2!=1)
# Out:
# True

# %%
(1 != 1) or (2 == 2) or (3 != 3) or (4 != 4)
# Out:
# True

# %%
(1 == 1) & (2 == 2) & (3 == 3) & (4 != 4)
# Out:
# False

# %%
(1 != 1) | (2 == 2) | (3 != 3) | (4 != 4)
# Out:
# True

# %% [markdown]
# ## Bitwise Operators
# ----
#
# | Symbol        | Description |
# | ------------- |:-------------:|
# | `or`  | Logical OR |
# | `&` | Logical AND |
# | `^` | XOR |
# | `~` | Negate |
# | `>>` | Right shift |
# | `<<`| Left shift |

# %%
a = 2 #10
b = 3 #11
print(a & b)
bin(a&b)
# Out:
# 2
# '0b10'

# %%
5 >> 1
# Out:
# 2

# %%
5 << 1
# Out:
# 10

# %%
Image("../src/photos/question_kitteh.png")

# %% [markdown]
# ## Lists
# ---
# One of the workhorses of python's data types
# * Lists allow you to push data into an ordered set of values
# * Lists also let you access data by indexing

# %%
l = ['apple', 'pear', 'peaches']
print(l)
# Out:
# ['apple', 'pear', 'peaches']

# %% [markdown]
# ## List Indexing
# ---
# * Lists can be indexed using sqaure brackets to retrieve and element

# %%
# you can access the indexed element of the list using bracket syntax
print(l[1])
# Out:
# pear

# %%
# you can append to a list, making it mutable
l.append('nutella')
l
# Out:
# ['apple', 'pear', 'peaches', 'nutella']

# %% [markdown]
# ## List Slicing
# ---
# * Lists can be indexed using sqaure brackets to retrieve a range of positions

# %%
# you can combine data types inside of lists as wellb
combo_list = ['first', 'second', 'third', 9,8,7]
combo_list
# Out:
# ['first', 'second', 'third', 9, 8, 7]

# %%
combo_list[0:2]
# Out:
# ['first', 'second']

# %%
combo_list[:2]
# Out:
# ['first', 'second']

# %%
combo_list.append("appended")
combo_list.append("going to remove")

# %%
combo_list
# Out:
# ['first',
#  'second',
#  'third',
#  9,
#  8,
#  7,
#  'appended',
#  'appended',
#  'going to remove']

# %%
combo_list.remove("going to remove")

# %%
combo_list[2:]
# Out:
# ['third', 9, 8, 7, 'appended']

# %%
combo_list.insert(1,"right after beginning")
combo_list
# Out:
# ['first', 'right after beginning', 'second', 'third', 9, 8, 7, 'appended']

# %%
nested_list = [combo_list,['inner','list']]
nested_list
# Out:
# [['first', 'second', 'third', 9, 8, 7], ['inner', 'list']]

# %%
nested_list[1][:]
# Out:
# ['inner', 'list']

# %% [markdown]
# ### State and Identity
# ----
# * State is not identity
# * Compare state with `==` compare identity with `is`
# * Comparing *identity*, check for equality of reference
# * Comparing *state*, check for equality of values

# %%
X = [3,4]
Y = [3]
Y.append(4)

# %%
X == Y
# Out:
# True

# %%
X is Y
# Out:
# False

# %%
Y.append(5)
print(X)
X = Y
X is Y
# Out:
# [3, 4]
# True

# %% [markdown]
# ## Variables are really References to a Value
# ----
# references are distinct from the values they refer to
# variables are the _names_ of reference

# %%
Image("../src/photos/fruit_basket.png")

# %%
fruit_basket = l
fruit_basket
# Out:
# ['apple', 'pear', 'peaches', 'nutella']

# %% [markdown]
# ### What happens when I change something in my basket?

# %%
fruit_basket.append('grapes')
print(l)
# Out:
# ['apple', 'pear', 'peaches', 'nutella', 'grapes']

# %% [markdown]
# ## Collections:
# ----
# Lists are examples of collections, they are a type, composed of other types
# * `tuple` => `(val1,val2)`
# * `set` => `{val1,val2}`
# * `dict` => `{'key1': val1, 'key2': val2}`

# %% [markdown]
# ### Tuples
# ----
# * Tuples are immutable

# %%
tup1 = (20, 'hi')
tup1
# Out:
# (20, 'hi')

# %%
print("This is Totally going to print",tup1[1])
tup1[0] = 10
# Out:
# This is Totally going to print hi
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-d7531c95c794> in <module>()
#       1 print("This is Totally going to print",tup1[1])
# ----> 2 tup1[0] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %%
type(tup1)
# Out:
# tuple

# %% [markdown]
# ### Dictionary
# ----
# * A Dictionary is the Key-Value store in python
# * Is is an unordered, changable, and indexed collection.

# %%
dict1 = {'name': "Tom", "grade": 3.5}
dict1[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-96ce6d9835b2> in <module>()
#       1 dict1 = {'name': "Tom", "grade": 3.5}
# ----> 2 dict1[0]
#
# KeyError: 0

# %%
dict1['name']
# Out:
# 'Tom'

# %%
dict1_new = {"name" : ["Tom", "Sam", "Raj", "Jessica"], "grade" : [3.5, 2.4, 3.8]}
dict1_new['name']
# Out:
# ['Tom', 'Sam', 'Raj', 'Jessica']

# %%
dict1_new.keys()
# Out:
# dict_keys(['name', 'grade'])

# %%
dict1_new.values()
# Out:
# dict_values([['Tom', 'Sam', 'Raj', 'Jessica'], [3.5, 2.4, 3.8]])

# %% [markdown]
# ## Sets
# ----
# * Lists might contain duplicate values, sets do not
# * `set()` or declare it literally with `{ }`

# %%
X = set([1,2,3,4])
X
# Out:
# {1, 2, 3, 4}

# %%
next_set = {1988, 1999}
type(next_set)
# Out:
# set

# %%
next_set.add(2010)
next_set
# Out:
# {1988, 1999, 2010}

# %% [markdown]
# ## Conditionals and Control Flow
# ----
# Indentation plays a significant role in Python's ability to understand whats nested inside of the Scope of another functions execution call.
#
# * white space affects semantics of python code

# %%
Image("../src/photos/control_flow.png")

# %%
help('if')
# Out:
# The "if" statement
# ******************
#
# The "if" statement is used for conditional execution:
#
#    if_stmt ::= "if" expression ":" suite
#                ("elif" expression ":" suite)*
#                ["else" ":" suite]
#
# It selects exactly one of the suites by evaluating the expressions one
# by one until one is found to be true (see section Boolean operations
# for the definition of true and false); then that suite is executed
# (and no other part of the "if" statement is executed or evaluated).
# If all expressions are false, the suite of the "else" clause, if
# present, is executed.
#
# Related help topics: TRUTHVALUE

# %%
x = 25
if x > 0:
    print('x is strictly positive')
    print(x)
print("I'm Done executing")
# Out:
# x is strictly positive
# 25
# I'm Done executing

# %% [markdown]
# ## Iteration
# ----
# python's keyword `for` is used for iterating over collections

# %%
for i in l:
    print(i)
# Out:
# apple
# pear
# peaches
# nutella
# grapes

# %%
# This can get a little excessive if you leave your keyboard unlocked
for i in [0,1,3,4,5,6,7,8]:
    print("Coffee")
# Out:
# Coffee
# Coffee
# Coffee
# Coffee
# Coffee
# Coffee
# Coffee
# Coffee

# %% [markdown]
# #### `while` loops
# ----
# While loops will repeat an execution of a statement or group of statements until the condition is met.

# %%
x = 0

while x < 5:
    print('x = ',x)
    print(' x is > 5, adding 1 to x')
    x+=1
# Out:
# x =  0
#  x is > 10, adding 1 to x
# x =  1
#  x is > 10, adding 1 to x
# x =  2
#  x is > 10, adding 1 to x
# x =  3
#  x is > 10, adding 1 to x
# x =  4
#  x is > 10, adding 1 to x
# x =  5
#  x is > 10, adding 1 to x
# x =  6
#  x is > 10, adding 1 to x
# x =  7
#  x is > 10, adding 1 to x
# x =  8
#  x is > 10, adding 1 to x
# x =  9
#  x is > 10, adding 1 to x

# %% [markdown]
# ## Python's `range` function
# ----
# you can pass a start,stop, and incrementor to the range function to generate a variable of a certain length or step.

# %%
for i in range(5):
    print("Brew coffee")
# Out:
# Brew coffee
# Brew coffee
# Brew coffee
# Brew coffee
# Brew coffee

# %% [markdown]
# #### List Comprehension
# ----
# These get fun

# %%
name = "Tom Goodheart"

# %%
empty_list = []
for i in name:
    empty_list.append(i)

# %%
empty_list
# Out:
# ['T', 'o', 'm', ' ', 'G', 'o', 'o', 'd', 'h', 'e', 'a', 'r', 't']

# %%
empty_list = [i for i in name]

# %%
empty_list
# Out:
# ['T', 'o', 'm', ' ', 'G', 'o', 'o', 'd', 'h', 'e', 'a', 'r', 't']

# %%
num_list = [1,2,3,4,5]

# %%
num_list1 = []
for i in num_list:
    num_list1.append(i ** 2)

# %%
num_list1
# Out:
# [1, 4, 9, 16, 25]

# %%
num_list2 = [ i//2 for i in num_list1]
num_list2
# Out:
# [0, 2, 4, 8, 12]

# %%
num_list_even = [ i for i in num_list if i % 2 == 0]

# %%
num_list_even
# Out:
# [2, 4]

# %%
Image("../src/photos/finish_line.png")
